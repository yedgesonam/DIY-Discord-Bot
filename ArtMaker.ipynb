# %% [markdown]
# <a href="https://colab.research.google.com/github/yedgesonam/DIY-Discord-Bot/blob/main/ArtMaker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install --force-reinstall -v "openai==0.27.0"
# Out:
# Using pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.1/70.1 kB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 7.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 23.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.3/199.3 kB 18.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.5/61.5 kB 6.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.2/123.2 kB 12.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 157.0/157.0 kB 15.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.2/61.2 kB 6.5 MB/s eta 0:00:00
# ...

# %%
pip install pytrends google-auth google-auth-oauthlib google-auth-httplib2 google-api-python-client openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
pip install imgurpython
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for imgurpython: filename=imgurpython-1.1.7-py3-none-any.whl size=12554 sha256=aa0eea83ac48854498b1d37552683510c8b81ace51de1b3dd2f2b1ae95129ff3
#   Stored in directory: /root/.cache/pip/wheels/3d/f0/cc/4bf6a0aff9619e3da19eeeaa369d98d4ee378a0bc217aa45bf
# Successfully built imgurpython
# ...

# %%
pip install --upgrade imgurpython
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests
from pytrends.request import TrendReq
from googleapiclient.discovery import build
import openai
# from etsy2 import Etsy
# from etsy2.oauth import EtsyOAuthClient
import os
import json
import imgurpython
from imgurpython import ImgurClient
from PIL import Image, UnidentifiedImageError
from io import BytesIO
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from imgurpython.helpers.error import ImgurClientError
import requests
import json
from google.colab import drive
from urllib.parse import urlparse

# Mount your Google Drive. This will require you to validate your account by clicking on the link that will be displayed, and pasting the authorization code in the input box that will appear.
drive.mount('/content/drive')

def save_image_on_drive(image_path_or_url):
    # Define a new path where to save the image on your Google Drive
    directory_path = '/content/drive/My Drive/images'  # update this path to where you want to save the image

    #print("Preparing to save image on Google Drive...")
    # Create the directory if it does not exist
    os.makedirs(directory_path, exist_ok=True)

    # If the image path is a URL, download the image
    if image_path_or_url.startswith('http'):
        #print("Detected image URL.")
        # Parse the image file name from the url
        a = urlparse(image_path_or_url)
        image_filename = os.path.basename(a.path)
        print(f"Image filename: {image_filename}")

        # Generate a new image path
        new_image_path = os.path.join(directory_path, image_filename)
        #print(f"New image path: {new_image_path}")
        # Download and save the image to the new location
        #print("Starting to download the image...")
        response = requests.get(image_path_or_url)
        #print("Image downloaded, starting to save the image...")
        with open(new_image_path, 'wb') as file:
            file.write(response.content)
        print("Image saved on Google Drive. Path to file: ", new_image_path)
    else:
        # If the image path is not a URL, assume it's a local file path and just return it as is
        print("Detected local file path.")
        new_image_path = image_path_or_url
        print("Local file path: ", new_image_path)

    # Return the new image path
    #print("save_image: returing new image path")
    return new_image_path

# delete API keys before sharing
printful_api_key = "uBQwlZwmYKQFJxABgyl9IyAgKVHgindJY21YNZ6F"
GOOGLE_API_KEY = "AIzaSyBt58FDvNT3MPkkLG6hCMO00gvRWokDplo"
OPENAI_API_KEY = "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"
DALLE_API_KEY = "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"


# Waiting for etsy approval: https://www.etsy.com/developers/register/preview/1166245205433
ETSY_API_KEY = "f1ifdbiu7mrnou7apyear5ma"
ETSY_API_SECRET = "ntruhr82d4"
#didnt receive this additional OAUTH from etsy so cant code this out alas
#ETSY_ACCESS_TOKEN = "YOUR_ETSY_ACCESS_TOKEN"
#ETSY_ACCESS_SECRET = "YOUR_ETSY_ACCESS_SECRET"

#imgur api
IMGUR_CLIENT_ID = '595338bb3c21eaf'
IMGUR_CLIENT_SECRET = '40b8ce112eda0edffc3f334ea83c0439ecfadd81'

#reddit api
CLIENT_ID = "lTF7VASUlvaOoHZl0sRx1g"
CLIENT_SECRET = "2o-lAs4vM5Ti1TCUD-duFT4DwZL-Xg"
USER_AGENT = "python:CornellDavidPublishing:v1.0 (by /u/CornellPublishing)"

def save_image(image_url, filepath):
    """
    Downloads an image from a URL and saves it to a file.
    Args:
        image_url (str): The URL of the image to download.
        filepath (str): The full path where the image will be saved, including the filename.
    """
    response = requests.get(image_url)
    img = Image.open(BytesIO(response.content))
    img.save(filepath)

#new code to integarte etsy

def upload_image_to_imgur(image_path):
    url = "https://api.imgur.com/3/upload"
    client_id = '595338bb3c21eaf'
    headers = {'Authorization': f'Client-ID {client_id}'}

    with open(image_path, 'rb') as file:
        files = {'image': file}
        response = requests.post(url, headers=headers, files=files)

    if response.status_code == 200:
        json_data = response.json()
        image_link = json_data['data']['link']
        return image_link
    else:
        raise ValueError(f"Image upload failed. Error code: {response.status_code}")

# code to actually make the images

# Set up the APIs
pytrends = TrendReq()
openai.api_key = OPENAI_API_KEY
youtube = build("youtube", "v3", developerKey=GOOGLE_API_KEY)

def get_trends(prompt):
    pytrend = TrendReq()
    # Build the payload
    pytrend.build_payload(kw_list=[prompt])
    # Get Google Keyword Suggestions
    suggestions = pytrend.suggestions(keyword=prompt)
    # Get related topics
    related_topics = pytrend.related_topics()
    # Get related queries
    related_queries = pytrend.related_queries()
    # Return data
    return {
        'suggestions': suggestions,
        'related_topics': related_topics,
        'related_queries': related_queries
    }

#removed youtube trends but can include it later if you want to since it works with same API
def search_youtube(query):
    search_response = youtube.search().list(
        q=query,
        part="id,snippet",
        type="video",
        videoDefinition="high",
        maxResults=5
    ).execute()

    return [{'title': item['snippet']['title'], 'url': f"https://www.youtube.com/watch?v={item['id']['videoId']}"} for item in search_response['items']]

def generate_description(prompt, rising_queries):
    n = 5 # set n as per your requirement
    print("The prompt part of the text from user is", prompt)
    print("The prompt for GPT")
    # Convert the DataFrame to a dictionary
    rising_queries_dict = rising_queries.to_dict()
    # Extract the 'query' values and join them into a string
    rising_queries_str = ', '.join([query for query in rising_queries_dict['query'].values()])
    combined_prompt = f"Write a prompt for DALLE that makes art based on the following trend. Exclude the word DALLE in your response. Make sure to include an art style and artist name too. Integarte this {prompt} art with one of the below current trends that's most relevant. Chose the most relevant from this list of current trends: {rising_queries_str}"
    print(combined_prompt)

    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=[{"role": "user", "content": combined_prompt}],
        n=n,
        max_tokens=100,
    )
    prompts = [choice["message"]["content"].strip() for choice in response["choices"]]
    return prompts

def generate_art(prompts, n=1):
    images = []
    for prompt in prompts:
        response = requests.post(
            "https://api.openai.com/v1/images/generations",
            headers={
                "Content-Type": "application/json",
                "Authorization": f"Bearer {DALLE_API_KEY}",
            },
            data=json.dumps({"model": "image-alpha-001", "prompt": prompt, "num_images": n}),
        )
        response_json = response.json()

        if 'data' in response_json and len(response_json['data']) > 0:
            image_url = response_json["data"][0]["url"]
            images.append({"prompt": prompt, "image_url": image_url})
        else:
            print(f"No data received from the API for prompt: {prompt}. Response: {response_json}")

    return images

def display_images(art_results):
    for i, art in enumerate(art_results):
        image_url = art['image_url']
        response = requests.get(image_url)
        img = mpimg.imread(BytesIO(response.content))
        imgplot = plt.imshow(img)
        print("index",i)
        print(f"Prompt: ", art['prompt']) # print the prompt as text
        plt.show()

    save_images_option = input("Do you want to save any of the images? (y/n): ")
    if save_images_option.lower() == "y":
        images_to_save = input("Enter the indices of the images you want to save (separated by commas): ")
        print("Example: If you want to save the first and third image, enter: 1, 3")
        indices = images_to_save.split(",")
        for index in indices:
            try:
                i = int(index.strip()) - 1
                if i >= 0 and i < len(art_results):
                    image_url = art_results[i]['image_url']
                    save_image(image_url, f'image_{i}.png')
            except ValueError:
                continue

        print("Selected images have been saved.")

import requests
import os
import os
import requests
import base64

def upload_image_to_printful(image_url, product_id=None):
    printful_api_key = "uBQwlZwmYKQFJxABgyl9IyAgKVHgindJY21YNZ6F"  # Replace with your actual Printful API key
    image_path = save_image_on_drive(image_url)
    print("image url in printful:", image_url)
    print("image path:", image_path)

    url = "https://api.printful.com/mockup-generator/create-task"
    headers = {
        "Authorization": "Bearer " + base64.b64encode(printful_api_key.encode()).decode()
    }

    # Extract image format from URL
    image_extension = os.path.splitext(image_url)[1].lower().replace(".", "")
    if image_extension == "jpeg":
        image_format = "jpg"
    else:
        image_format = image_extension

    data = {
        "variant_ids": [4012, 4013, 4014],
        "format": image_format,
        "files": [
            {
                "placement": "front",
                "image_url": image_path,
                "position": {
                    "area_width": 1800,
                    "area_height": 2400,
                    "width": 1800,
                    "height": 1800,
                    "top": 300,
                    "left": 0
                }
            }
        ]
    }
    print(data)

    try:
        response = requests.post(url, json=data, headers=headers)
        if response.status_code == 200:
            response_data = response.json()
            task_id = response_data.get("result").get("id")
            return task_id
        else:
            print("Failed to create a task on Printful. Status code:", response.status_code)
            return None
    except requests.RequestException as err:
        print("Something went wrong with the request:", err)
        return None


def main():
    # Ask the user for a keyword to search for
    keyword = input("Enter your keyword: ")
    # Get trends related to the keyword
    trends = get_trends(keyword)

    if trends:
        # Display trending topics
        print("Trending topics: ", trends['related_topics'])
        # Display related queries
        print("Related queries: ", trends['related_queries'])
        print("Now, let's print only rising queries.")
        # Check if the keyword is in the related queries
        if keyword in trends['related_queries']:
            # Extract the 'rising' data for the keyword
            rising_queries = trends['related_queries'][keyword]['rising']
            # Print the top rising queries
            print(rising_queries)
        else:
            print(f"No rising queries found for keyword: {keyword}")
        # Display suggestions
        print("Suggestions: ", trends['suggestions'])
    else:
        print("Unable to fetch trends for the provided keyword.")

    # Generate art description
    user_input = keyword
    gpt_description = generate_description(user_input, rising_queries)
    print("Generated art description: ", gpt_description)
    # Generate art and display with DALLE
    result = generate_art(gpt_description)
    print("DALLE Generated art: ", result)
    display_images(result)
    # Save the first image to a local file (you can modify this to save all images if you want)
    first_image_url = result[0]['image_url']
    save_image(first_image_url, f'{keyword}.png')
    # Create a new Etsy listing using the generated image
    title = "My Digital Item"
    description = "This is a test digital item."
    image_url = f'{keyword}.png'  # path to your image
    price = "19.99"
    quantity = 1
    # First, upload the image to Imgur to make it accessible over the internet
    image_url = upload_image_to_imgur(image_url)
    print(image_url)

    # Declare task_id variable before the if statement
    task_id = None
    # Upload the image to Printful
    task_id = upload_image_to_printful(image_url)
    if task_id:
        print("Image uploaded successfully to Printful. Task ID:", task_id)
    else:
        print("Failed to upload the image to Printful.")


if __name__ == "__main__":
    main()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Enter your keyword: mugler
# Trending topics:  {'mugler': {'rising':     value formattedValue                                            link  \
# 0   22800       Breakout  /trends/explore?q=/g/11b73tb7x5&date=today+5-y
# 1    5950       Breakout      /trends/explore?q=/m/0678n6&date=today+5-y
# 2    5450       Breakout       /trends/explore?q=/m/03bpv&date=today+5-y
# 3    4300        +4,300%      /trends/explore?q=/m/0b2nk7&date=today+5-y
# 4    3100        +3,100%      /trends/explore?q=/m/01d8pr&date=today+5-y
# 5    2300        +2,300%      /trends/explore?q=/m/04nk84&date=today+5-y
# 6    2200        +2,200%    /trends/explore?q=/m/0105f_d9&date=today+5-y
# 7    2200        +2,200%      /trends/explore?q=/m/02vqw3&date=today+5-y
# 8    2100        +2,100%     /trends/explore?q=/m/0fq22vb&date=today+5-y
# ...

# %%
curl --location --request POST 'https://api.printful.com/mockup-generator/create-task/71' \
--header 'Authorization: Bearer uBQwlZwmYKQFJxABgyl9IyAgKVHgindJY21YNZ6F ' \
--data-raw '{
    "variant_ids" : [4012, 4013, 4014],
    "format": "jpg",
    "files" : [
        {
            "placement": "front",
            "image_url": "/content/drive/My Drive/images/HiDqIhZ.jpeg",
            "position": {
                "area_width": 1800,
                "area_height": 2400,
                "width": 1800,
                "height": 1800,
                "top": 300,
                "left": 0
            }
        }
    ]
}'
# Out:
#   File "<ipython-input-7-5f8b72866c1d>", line 3
#     --data-raw '{
#                ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
import requests
import json

# Your Printful API Key
API_KEY = 't4JUolvu1zg4oVzxJoo4Aq0zb4tuMiirN0u4I7VC'

# The URL of the image you want to put on the iPhone cover
image_url = '/content/drive/My Drive/images/HiDqIhZ.jpeg'

# Variant ID for the iPhone cover
variant_id = 4012 # replace with your correct variant ID

product_id =16181570359

# Endpoint URL for the mockup creation task
# Endpoint URL for the mockup creation task
url = 'https://api.printful.com/mockup-generator/create-task/' + str(product_id)


# Define the payload
payload = {
    "format": "jpg",
    "files": [
        {
            "url": image_url,
            "placement": "default"
        }
    ],
    "options": {
        "preview_width": 1000,
        "preview_height": 1000
    },
    "variant_ids": [variant_id]
}

headers = {
    'Content-Type': 'application/json',
    'Authorization': 'Bearer ' + API_KEY
}

# Make the POST request
response = requests.request('POST', url, headers=headers, data=json.dumps(payload))

# Parse the response
response_data = response.json()

if response.status_code == 200:
    print(f"Mockup creation task started. Task key: {response_data['result']['task_key']}")
else:
    print(f"Error creating mockup: {response_data['error']}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-ccbfc301779c> in <cell line: 15>()
#      13 # Endpoint URL for the mockup creation task
#      14 # Endpoint URL for the mockup creation task
# ---> 15 url = 'https://api.printful.com/mockup-generator/create-task/' + str(product_id)
#      16
#      17
#
# NameError: name 'product_id' is not defined

# %%
import requests
import json

# Set your variables
id = 71
oauth_token = "y8pT3vRTXBJRocbnDdfov8RSno6VmRqEAdG8bByD"

# Define the API endpoint
url = f'https://api.printful.com/mockup-generator/create-task/{id}'

# Define the headers for the request
headers = {
    'Authorization': f'Bearer {oauth_token}',
}

# Define the payload for the POST request
payload = {
    "variant_ids" : [4012, 4013, 4014, 4017, 4018, 4019],
    "format": "jpg",
    "files" : [
        {
            "placement": "front",
            "image_url": "https://i.imgur.com/2bYfOTB.png",
            "position": {
                "area_width": 1800,
                "area_height": 2400,
                "width": 1800,
                "height": 1800,
                "top": 300,
                "left": 0
            }
        },
        {
            "placement": "back",
            "image_url": "http://your-site/path-to-back-printfile.jpg",
            "position": {
                "area_width": 1800,
                "area_height": 2400,
                "width": 1800,
                "height": 1800,
                "top": 300,
                "left": 0
            }
        }
    ]
}

# Make the POST request
response = requests.post(url, headers=headers, data=json.dumps(payload))

# Output the result
print(response.json())
# Out:
# {'code': 200, 'result': {'task_key': 'gt-523371849', 'status': 'pending'}, 'extra': []}
